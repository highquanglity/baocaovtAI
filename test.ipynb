# %%
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

# Load the image
image_path = "bang-hieu-bia-sai-gon-6.jpg"  # Replace with your image path
image = Image.open(image_path)

# Define the bounding boxes and text labels
bounding_boxes = [
    {"bbox_2d": (15, 160, 128, 237), "label": "BIA SAIGON"},
    {"bbox_2d": (204, 129, 388, 160), "label": "LAOSUM BBQ"},
    {"bbox_2d": (204, 160, 448, 181), "label": "CHUYÊN ẨM THỰC LÀO - THÁI"},
    {"bbox_2d": (204, 181, 448, 202), "label": "ĐẶC SẢN SÚM - LẨU - NƯỚNG LÀO"},
    {"bbox_2d": (204, 202, 448, 223), "label": "ĐC: 03 LÊ TRUNG ĐÌNH, P. TÂY LỘC, TP. HUẾ"},
    {"bbox_2d": (204, 223, 320, 244), "label": "ĐT: 0985 13 2277"},
    {"bbox_2d": (435, 160, 548, 237), "label": "BIA SAIGON"},
    {"bbox_2d": (108, 244, 188, 265), "label": "BIA SAIGON"},
    {"bbox_2d": (198, 244, 318, 265), "label": "BẤT SẢNG KHÓA"},
    {"bbox_2d": (278, 244, 358, 265), "label": "HỦU HIỀN"},
    {"bbox_2d": (108, 265, 188, 286), "label": "SAIGON"},
    {"bbox_2d": (238, 390, 288, 411), "label": "SAIGON"},
    {"bbox_2d": (238, 411, 288, 432), "label": "LAOSUM BBQ"},
    {"bbox_2d": (10, 388, 238, 432), "label": "banghieu minhkhang.com"}
]

# Draw bounding boxes and labels on the image
draw = ImageDraw.Draw(image)
for bbox in bounding_boxes:
    x1, y1, x2, y2 = bbox["bbox_2d"]
    label = bbox["label"]

    # Draw the bounding box
    draw.rectangle([x1, y1, x2, y2], outline="green", width=2)

    # Draw the label inside the bounding box
    draw.text((x1 + 5, y1 + 5), label, fill="white")

# Display the image with bounding boxes
plt.figure(figsize=(10, 8))
plt.imshow(image)
plt.axis("off")
plt.show()
